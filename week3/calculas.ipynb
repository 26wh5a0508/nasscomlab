# %%
import numpy as np
import sympy as sp

x, y = sp.symbols('x y')
sp.init_printing()
np.random.seed(42)
print('Setup complete. SymPy', sp.__version__, '| NumPy', np.__version__)
# Out:
# Setup complete. SymPy 1.14.0 | NumPy 2.0.2

# %%
def f(x):
    return x**4

h = 1e-6
slope_at_3 = (f(3 + h) - f(3)) / h
print('Numerical f\'(3):', round(slope_at_3, 4), ' (exact = 6)')
# Out:
# Numerical f'(3): 108.0001  (exact = 6)

# %%
def g(x):
  return x**5 +x*2

# %%
# ----partal derivative
f2 = x**3 + 3*x*2*y + y**2
print('df/dx =', sp.diff(f2, x))
print('df/dy =', sp.diff(f2, y))
# Out:
# df/dx = 3*x**2 + 6*y
# df/dy = 6*x + 2*y

# %%
# ----GRADIENT
grad = [sp.diff(f2, v) for v in (x, y)]
print('grad f =', grad)
grad_at = [g.subs({x: 1, y: 2}) for g in grad]
print('grad f at (1, 0) =', grad_at)
# Out:
# grad f = [3*x**2 + 6*y, 6*x + 2*y]
# grad f at (1, 0) = [15, 10]

# %%
h2=x**2 *y + sp.sin(y)

# %%
#------ CHAIN RULE BY HAND vs SymPy
by_hand = sp.sin(x**2) * 3*x
by_sympy = sp.diff(sp.sin(x**4), x)

print('By hand :', by_hand)
print('By SymPy:', by_sympy)
print('Match?  ', sp.simplify(by_hand - by_sympy) == 0)
# Out:
# By hand : 3*x*sin(x**2)
# By SymPy: 4*x**3*cos(x**4)
# Match?   False

# %%
# y = exp(x**2 + 1);  inner = x**2 + 1, inner' = 2x, outer' = exp(inner)

# %%
X = np.random.randn(4, 3)
Y = np.random.randn(4, 1)
W1 = np.random.randn(3, 5) * 0.1
W2 = np.random.randn(5, 1) * 0.1

z1 = X @ W1
h  = np.maximum(0, z1)
y_hat = h @ W2
loss = ((y_hat - Y) ** 2).mean()
print('Initial loss:', round(loss, 4))
# Out:
# Initial loss: 1.6936

# %%
# ---BACKWARD PASS (gradients via the chain rule)
dy   = 4 * (y_hat - Y) / Y.size
dW2  = h.T @ dy
dh   = dy @ W2.T
dz1  = dh * (z1 > 0)
dW1  = X.T @ dz1

print('dW1 shape:', dW1.shape, '(matches W1)')
print('dW2 shape:', dW2.shape, '(matches W2)')
# Out:
# dW1 shape: (3, 5) (matches W1)
# dW2 shape: (5, 1) (matches W2)

# %%
# 🔹 4C. ONE GRADIENT-DESCENT
lr = 0.1
W1 -= lr * dW1
W2 -= lr * dW2
h_new = np.maximum(0, X @ W1)
loss_new = ((h_new @ W2 - Y) ** 2).mean()
print('Loss before:', round(loss, 3))
print('Loss after :', round(loss_new, 4), '-> should be lower')
# Out:
# Loss before: 1.694
# Loss after : 1.6017 -> should be lower

# %%
# forward backward onestep
Xb = np.random.randn(6, 4)
Yb = np.random.randn(6, 1)
Wa = np.random.randn(4, 8) * 0.1
Wb = np.random.randn(8, 1) * 0.1

# %%
f5 = x**3 + 6*x*y + y**3
H = sp.hessian(f5, (x, y))
print('Hessian of f:')
sp.pprint(H)
# Out:
# Hessian of f:
# ⎡6⋅x   6 ⎤
# ⎢        ⎥
# ⎣ 6   6⋅y⎦

# %%
xv = 0.0
lr = 0.2
for step in range(15):
    grad = 2 * (xv - 4)
    xv = xv - lr * grad
print('Converged x:', round(xv, 3), ' (true minimum = 4)')
# Out:
# Converged x: 3.998  (true minimum = 4)

# %%
# 1. Hessian of x**4 + y**2
